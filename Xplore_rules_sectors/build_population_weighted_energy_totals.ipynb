# %% [markdown]
# # Rule: **build_population_weighted_energy_totals**

# %% [markdown]
# **Description**
#
# Distribute country-level energy demands by population.
#
# For `kind`=`energy`: use data for year defined in config file (*energy:energy_totals_year*).
#
# For `kind`=`heat`: use data for cutout year.

# %% [markdown]
# **Outputs**
#
# - resources/`pop_weighted_{kind}_totals_s_{clusters}.csv`

# %%
######################################## Parameters

### Run
name = 'case_SectorCoupled'
prefix = ''

### Network
clusters = 5

# %%
##### Import packages
import matplotlib.pyplot as plt
import os 
import sys
import numpy as np


##### Import local functions
sys.path.append(os.path.abspath(os.path.join('..')))
import functions as xp


##### Read params.yaml
params = xp.read_params('../params.yaml')


##### Ignore warnings
import warnings
warnings.filterwarnings('ignore', category=UserWarning)

# %% [markdown]
# ## `pop_weighted_{energy}_totals_s_{clusters}.csv`

# %% [markdown]
# Load the file and preview its content.

# %%
file = f"pop_weighted_energy_totals_s_{clusters}.csv"

df_energy_totals = xp.load_file_csv(
    params,
    file,
    prefix=prefix,
    name=name,
    location="resources",
    index_col="name",
)

df_energy_totals.head()

# %% [markdown]
# ## `pop_weighted_{heat}_totals_s_{clusters}.csv`

# %% [markdown]
# Load the file and preview its content.

# %%
file = f"pop_weighted_heat_totals_s_{clusters}.csv"

df_heat_totals = xp.load_file_csv(
    params,
    file,
    prefix=prefix,
    name=name,
    location="resources",
    index_col="name",
)

df_heat_totals.head()
