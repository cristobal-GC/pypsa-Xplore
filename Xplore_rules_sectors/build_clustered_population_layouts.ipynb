# %% [markdown]
# # Rule: **build_clustered_population_layouts**

# %% [markdown]
# **Description**
#
# Build population layouts for all clustered model regions as total as well as split by urban and rural population.

# %% [markdown]
# **Outputs**
#
# - resources/`pop_layout_base_s_{clusters}.csv`

# %%
######################################## Parameters

### Run
name = 'case_SectorCoupled'
prefix = ''

### Network
clusters = 5

# %%
##### Import packages
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import os 
import sys
import numpy as np
import xarray as xr


##### Import local functions
sys.path.append(os.path.abspath(os.path.join('..')))
import functions as xp


##### Read params.yaml
params = xp.read_params('../params.yaml')


##### Ignore warnings
import warnings
warnings.filterwarnings('ignore', category=UserWarning)

# %% [markdown]
# ## `pop_layout_base_s_{clusters}.csv`

# %% [markdown]
# Load the file and preview its content.

# %%
file = f'pop_layout_base_s_{clusters}.csv'
path = f'{params["rootpath"]}/resources/{prefix}/{name}/'

df = xp.load_file_csv(
    params,
    file,
    prefix=prefix,
    name=name,
    location="resources",
)

df.head()
